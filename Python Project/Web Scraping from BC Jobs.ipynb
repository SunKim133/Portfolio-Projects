# %% [markdown]
# # Which Skill Set Is Most Needed?: Web Scraping from BC Jobs
#
# This project aims to build a web scraping tool using the `BeautifulSoup` library to extract job postings data from [BC Jobs](https://www.bcjobs.ca/). The focus of this project is to extract data related to Data Analyst job postings and analyze the technical skill requirements that are most in demand.
#
# The project involves scraping job postings data using various technical skills as keywords for the search query. The data extracted from each search query will be saved in a structured format, which can then be used to analyze the technical skills that are most in demand for Data Analyst roles in British Columbia.
#
# The analysis will include identifying the frequency of each technical skill requirement across job postings. This information can be used to provide insights to job seekers looking to pursue a career in Data Analysis in British Columbia and also to employers looking to hire Data Analysts.
#
# As the final output, I will summarize the findings and provide recommendations based on the insights gained from the data analysis.
#
#
# ## Building Web Scraping Model
#
# To build a web scraping model, we first need to import necessary libraries such as `BeautifulSoup` and `requests`, and retrieve the webpage using BeautifulSoup and requests. We will be using the keyword 'Python' to search for job postings related to this skill set. To filter out outdated job posts, we will only retrieve data that have been posted within the last month.

# %%
# Import libraries
from bs4 import BeautifulSoup
import requests
import json

html_text = requests.get('https://www.bcjobs.ca/search-jobs?q=python&location=#page=1&q=python&location=&range=0&freshness=31&categoryIds=&employerTypeIds=&positionTypeIds=&memberStatusIds=&careerLevelIds=&featuredEmployersOnly=false&trainingPositionsOnly=false').text
soup = BeautifulSoup(html_text, 'html.parser')
jobs = soup.find_all('a', class_='list-item-wrapper')

print(jobs)
# Out:
# [<a class="list-item-wrapper clearfix odd" href="/jobs/web-developer-burnaby-1056458" target="_self" title="Web Developer">
# <div class="col-xs-12 col-sm-8 u_p-none">
# <div class="text-16 list-item-title text-limit text-bold">Web Developer</div>
# <div class="list-divider flex-w100">
# <div class="text-limit">Fortinet</div>
# </div>
# </div>
# <div class="col-xs-12 col-sm-4 text-right xs-text-left u_p-none">
# <strong>May. 9, 2023</strong><br/>
# Burnaby, BC<br/>
# </div>
# </a>, <a class="list-item-wrapper clearfix even" href="/jobs/senior-cloud-developer-burnaby-1022693" target="_self" title="Senior Cloud Developer">
# <div class="col-xs-12 col-sm-8 u_p-none">
# <div class="text-16 list-item-title text-limit text-bold">Senior Cloud Developer</div>
# <div class="list-divider flex-w100">
# <div class="text-limit">Fortinet</div>
# </div>
# </div>
# <div class="col-xs-12 col-sm-4 text-right xs-text-left u_p-none">
# <strong>May. 9, 2023</strong><br/>
# Burnaby, BC<br/>
# </div>
# </a>, <a class="list-item-wrapper clearfix odd" href="/jobs/release-qa-specialist-burnaby-1079339" target="_self" title="Release QA Specialist">
# <div class="col-xs-12 col-sm-8 u_p-none">
# <div class="text-16 list-item-title text-limit text-bold">Release QA Specialist</div>
# <div class="list-divider flex-w100">
# <div class="text-limit">Fortinet</div>
# </div>
# </div>
# <div class="col-xs-12 col-sm-4 text-right xs-text-left u_p-none">
# <strong>May. 11, 2023</strong><br/>
# Burnaby, BC<br/>
# </div>
# </a>, <a class="list-item-wrapper clearfix even" href="/jobs/devops-specialist-burnaby-927734" target="_self" title="DevOps Specialist">
# <div class="col-xs-12 col-sm-8 u_p-none">
# <div class="text-16 list-item-title text-limit text-bold">DevOps Specialist</div>
# <div class="list-divider flex-w100">
# <div class="text-limit">Fortinet</div>
# </div>
# </div>
# <div class="col-xs-12 col-sm-4 text-right xs-text-left u_p-none">
# <strong>May. 8, 2023</strong><br/>
# Burnaby, BC<br/>
# </div>
# </a>, <a class="list-item-wrapper clearfix odd" href="/jobs/software-dev-qa-burnaby-1077727" target="_self" title="Software Dev QA">
# <div class="col-xs-12 col-sm-8 u_p-none">
# <div class="text-16 list-item-title text-limit text-bold">Software Dev QA</div>
# <div class="list-divider flex-w100">
# <div class="text-limit">Fortinet</div>
# </div>
# </div>
# <div class="col-xs-12 col-sm-4 text-right xs-text-left u_p-none">
# <strong>May. 10, 2023</strong><br/>
# Burnaby, BC<br/>
# </div>
# </a>, <a class="list-item-wrapper clearfix even" href="/jobs/software-dev-qa-burnaby-1080005" target="_self" title="Software Dev QA">
# <div class="col-xs-12 col-sm-8 u_p-none">
# <div class="text-16 list-item-title text-limit text-bold">Software Dev QA</div>
# <div class="list-divider flex-w100">
# <div class="text-limit">Fortinet</div>
# </div>
# </div>
# <div class="col-xs-12 col-sm-4 text-right xs-text-left u_p-none">
# <strong>May. 10, 2023</strong><br/>
# Burnaby, BC<br/>
# </div>
# </a>, <a class="list-item-wrapper clearfix odd" href="/jobs/senior-consultant-full-stack-developer-vancouver-1332852" target="_self" title="Senior Consultant, Full Stack Developer">
# <div class="col-xs-12 col-sm-8 u_p-none">
# <div class="text-16 list-item-title text-limit text-bold">Senior Consultant, Full Stack Developer</div>
# <div class="list-divider flex-w100">
# <div class="text-limit">KPMG</div>
# </div>
# </div>
# <div class="col-xs-12 col-sm-4 text-right xs-text-left u_p-none">
# <strong>May. 8, 2023</strong><br/>
# Vancouver, BC<br/>
# </div>
# </a>, <a class="list-item-wrapper clearfix even" href="/jobs/technical-support-expert-fortiedr-burnaby-1073081" target="_self" title="Technical Support Expert - FortiEDR">
# <div class="col-xs-12 col-sm-8 u_p-none">
# <div class="text-16 list-item-title text-limit text-bold">Technical Support Expert - FortiEDR</div>
# <div class="list-divider flex-w100">
# <div class="text-limit">Fortinet</div>
# </div>
# </div>
# <div class="col-xs-12 col-sm-4 text-right xs-text-left u_p-none">
# <strong>May. 10, 2023</strong><br/>
# Burnaby, BC<br/>
# </div>
# </a>, <a class="list-item-wrapper clearfix odd" href="/jobs/software-developer-fortiai-burnaby-1022695" target="_self" title="Software Developer - FortiAI">
# <div class="col-xs-12 col-sm-8 u_p-none">
# <div class="text-16 list-item-title text-limit text-bold">Software Developer - FortiAI</div>
# <div class="list-divider flex-w100">
# <div class="text-limit">Fortinet</div>
# </div>
# </div>
# <div class="col-xs-12 col-sm-4 text-right xs-text-left u_p-none">
# <strong>May. 9, 2023</strong><br/>
# Burnaby, BC<br/>
# </div>
# </a>, <a class="list-item-wrapper clearfix even" href="/jobs/software-dev-qa-burnaby-969886" target="_self" title="Software Dev QA">
# <div class="col-xs-12 col-sm-8 u_p-none">
# <div class="text-16 list-item-title text-limit text-bold">Software Dev QA</div>
# <div class="list-divider flex-w100">
# <div class="text-limit">Fortinet</div>
# </div>
# </div>
# <div class="col-xs-12 col-sm-4 text-right xs-text-left u_p-none">
# <strong>May. 10, 2023</strong><br/>
# Burnaby, BC<br/>
# </div>
# </a>]

# %% [markdown]
# For the quick analysis, I'll use the first job posting for now.

# %%
job = soup.find('a', class_='list-item-wrapper')

print(job)
# Out:
# <a class="list-item-wrapper clearfix odd" href="/jobs/web-developer-burnaby-1056458" target="_self" title="Web Developer">
# <div class="col-xs-12 col-sm-8 u_p-none">
# <div class="text-16 list-item-title text-limit text-bold">Web Developer</div>
# <div class="list-divider flex-w100">
# <div class="text-limit">Fortinet</div>
# </div>
# </div>
# <div class="col-xs-12 col-sm-4 text-right xs-text-left u_p-none">
# <strong>May. 9, 2023</strong><br/>
# Burnaby, BC<br/>
# </div>
# </a>

# %%
job_title = job.find('div', class_='list-item-title').text

print(job_title)
# Out:
# Web Developer

# %%
company_name = job.find('div', class_='list-divider flex-w100').text.replace('\n', '')

print(company_name)
# Out:
# Fortinet

# %%
published_date = job.find('strong').text
published_date
# Out:
# 'May. 9, 2023'

# %%
link = job['href']

link
# Out:
# '/jobs/web-developer-burnaby-1056458'

# %% [markdown]
# It looks like this is a partial link. Let's add 'https://www.bcjobs.ca' in front of it so it can work properly.

# %%
link = "https://www.bcjobs.ca" + job['href']

print(link)
# Out:
# https://www.bcjobs.ca/jobs/web-developer-burnaby-1056458

# %% [markdown]
# Let's iterate the code for each job posting in the first page.

# %%
for job in jobs:
    job_title = job.find('div', class_='list-item-title').text
    company_name = job.find('div', class_='list-divider flex-w100').text.replace('\n', '')
    published_date = job.find('strong').text
    post_link = "https://www.bcjobs.ca" + job['href']
    
    if post_link:        
        print(f"Job Title: {job_title}")
        print(f"Company Name: {company_name}")
        print(f"Published Date: {published_date}")
        print(f"Link: {post_link}")
        print("")
# Out:
# Job Title: Web Developer
# Company Name: Fortinet
# Published Date: May. 9, 2023
# Link: https://www.bcjobs.ca/jobs/web-developer-burnaby-1056458
#
# Job Title: Senior Cloud Developer
# Company Name: Fortinet
# Published Date: May. 9, 2023
# Link: https://www.bcjobs.ca/jobs/senior-cloud-developer-burnaby-1022693
#
# Job Title: Release QA Specialist
# Company Name: Fortinet
# Published Date: May. 11, 2023
# Link: https://www.bcjobs.ca/jobs/release-qa-specialist-burnaby-1079339
#
# Job Title: DevOps Specialist
# Company Name: Fortinet
# Published Date: May. 8, 2023
# Link: https://www.bcjobs.ca/jobs/devops-specialist-burnaby-927734
#
# Job Title: Software Dev QA
# Company Name: Fortinet
# Published Date: May. 10, 2023
# Link: https://www.bcjobs.ca/jobs/software-dev-qa-burnaby-1077727
#
# Job Title: Software Dev QA
# Company Name: Fortinet
# Published Date: May. 10, 2023
# Link: https://www.bcjobs.ca/jobs/software-dev-qa-burnaby-1080005
#
# Job Title: Senior Consultant, Full Stack Developer
# Company Name: KPMG
# Published Date: May. 8, 2023
# Link: https://www.bcjobs.ca/jobs/senior-consultant-full-stack-developer-vancouver-1332852
#
# Job Title: Technical Support Expert - FortiEDR
# Company Name: Fortinet
# Published Date: May. 10, 2023
# Link: https://www.bcjobs.ca/jobs/technical-support-expert-fortiedr-burnaby-1073081
#
# Job Title: Software Developer - FortiAI
# Company Name: Fortinet
# Published Date: May. 9, 2023
# Link: https://www.bcjobs.ca/jobs/software-developer-fortiai-burnaby-1022695
#
# Job Title: Software Dev QA
# Company Name: Fortinet
# Published Date: May. 10, 2023
# Link: https://www.bcjobs.ca/jobs/software-dev-qa-burnaby-969886

# %% [markdown]
# Let's expand our web scraping model to retrieve job postings from every page of the search results and store the data in a variable named `python_results`.
#
# To achieve this, we'll loop through each page of the search results and extract the relevant job data using `BeautifulSoup` and `requests`. Once we've extracted all of the relevant job data, we'll store it in a Python list named `python_results`.

# %%
from bs4 import BeautifulSoup
import requests

base_url = "https://www.bcjobs.ca/search-jobs"
params = {
    "q": "python",
    "location": "",
    "range": "0",
    "freshness": "31",
    "categoryIds": "",
    "employerTypeIds": "",
    "positionTypeIds": "",
    "memberStatusIds": "",
    "careerLevelIds": "",
    "featuredEmployersOnly": "false",
    "trainingPositionsOnly": "false"
}

# Get the last page number
html_text = requests.get(base_url, params=params).text
soup = BeautifulSoup(html_text, "html.parser")
total_results = int(soup.find("strong", {"data-outlet": "total"}).text)
num_pages = total_results // 10 + 1 if total_results % 10 != 0 else total_results // 10

# Scrape the job postings from all pages and store the results in a variable
python_results = []
for page in range(1, num_pages + 1):
    params["page"] = page
    html_text = requests.get(base_url, params=params).text
    soup = BeautifulSoup(html_text, "html.parser")
    jobs = soup.find_all("a", class_="list-item-wrapper")

    for job in jobs:
        job_title = job.find("div", class_="list-item-title").text.strip()
        company_name = job.find("div", class_="list-divider flex-w100").text.strip()
        published_date = job.find("strong").text.strip()
        post_link = "https://www.bcjobs.ca" + job["href"]
        
        python_results.append({
            "Job Title": job_title,
            "Company Name": company_name,
            "Published Date": published_date,
            "Link": post_link
        })

# %%
print(f"There are {len(python_results)} job postings for Python")

for job in python_results:
    print(json.dumps(job, indent=4))
# Out:
# There are 115 job postings for Python
# {
#     "Job Title": "Web Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 9, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/web-developer-burnaby-1056458"
# }
# {
#     "Job Title": "Senior Cloud Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 9, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-cloud-developer-burnaby-1022693"
# }
# {
#     "Job Title": "Release QA Specialist",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 11, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/release-qa-specialist-burnaby-1079339"
# }
# {
#     "Job Title": "DevOps Specialist",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 8, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/devops-specialist-burnaby-927734"
# }
# {
#     "Job Title": "Software Dev QA",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/software-dev-qa-burnaby-1077727"
# }
# {
#     "Job Title": "Software Dev QA",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/software-dev-qa-burnaby-1080005"
# }
# {
#     "Job Title": "Senior Consultant, Full Stack Developer",
#     "Company Name": "KPMG",
#     "Published Date": "May. 8, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-consultant-full-stack-developer-vancouver-1332852"
# }
# {
#     "Job Title": "Technical Support Expert - FortiEDR",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/technical-support-expert-fortiedr-burnaby-1073081"
# }
# {
#     "Job Title": "Software Developer - FortiAI",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 9, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/software-developer-fortiai-burnaby-1022695"
# }
# {
#     "Job Title": "Software Dev QA",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/software-dev-qa-burnaby-969886"
# }
# {
#     "Job Title": "Staff Software Dev QA",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 9, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/staff-software-dev-qa-burnaby-1064411"
# }
# {
#     "Job Title": "Product Management Specialist - Public Cloud",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 9, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/product-management-specialist-public-cloud-burnaby-1073078"
# }
# {
#     "Job Title": "Web Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 9, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/web-developer-burnaby-1098653"
# }
# {
#     "Job Title": "Web Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 9, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/web-developer-burnaby-1098654"
# }
# {
#     "Job Title": "Web Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/web-developer-burnaby-1102468"
# }
# {
#     "Job Title": "AV Analyst",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 11, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/av-analyst-burnaby-1104356"
# }
# {
#     "Job Title": "Staff Software Dev QA",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 13, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/staff-software-dev-qa-burnaby-985590"
# }
# {
#     "Job Title": "DevOps Specialist",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 11, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/devops-specialist-burnaby-999004"
# }
# {
#     "Job Title": "Senior Network Specialist - MIS",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-network-specialist-mis-burnaby-1021159"
# }
# {
#     "Job Title": "DevOps Specialist",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/devops-specialist-burnaby-1113725"
# }
# {
#     "Job Title": "Software Developer (C/C++)",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/software-developer-c-c-burnaby-1095704"
# }
# {
#     "Job Title": "Senior Full-Stack Web Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-full-stack-web-developer-burnaby-1085461"
# }
# {
#     "Job Title": "Senior IT Specialist - Openstack",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 9, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-it-specialist-openstack-burnaby-1085464"
# }
# {
#     "Job Title": "Software Application Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 15, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/software-application-developer-burnaby-1121160"
# }
# {
#     "Job Title": "Embedded Software Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/embedded-software-developer-burnaby-1058181"
# }
# {
#     "Job Title": "AV Analyst",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 13, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/av-analyst-burnaby-1061722"
# }
# {
#     "Job Title": "Software Developer (C/C++)",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 11, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/software-developer-c-c-burnaby-1078469"
# }
# {
#     "Job Title": "Senior Software Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 11, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-software-developer-burnaby-954761"
# }
# {
#     "Job Title": "AV Analyst 1",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 11, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/av-analyst-1-burnaby-880933"
# }
# {
#     "Job Title": "Product Management Specialist",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 15, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/product-management-specialist-burnaby-1043616"
# }
# {
#     "Job Title": "Intermediate Software Developer - Redbrick",
#     "Company Name": "VIATEC",
#     "Published Date": "May. 11, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/intermediate-software-developer-redbrick-vancouver-island-victoria-1418496"
# }
# {
#     "Job Title": "IT Specialist - Openstack",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/it-specialist-openstack-burnaby-1103727"
# }
# {
#     "Job Title": "Embedded Software Developer 1",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 11, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/embedded-software-developer-1-burnaby-907145"
# }
# {
#     "Job Title": "Embedded Software Developer 2",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/embedded-software-developer-2-burnaby-909682"
# }
# {
#     "Job Title": "DevOps Software Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/devops-software-developer-burnaby-927735"
# }
# {
#     "Job Title": "Software Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 15, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/software-developer-burnaby-1089046"
# }
# {
#     "Job Title": "AV Analyst 1",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 8, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/av-analyst-1-burnaby-906106"
# }
# {
#     "Job Title": "Student Assistant, Computer Lab (Computer Science)",
#     "Company Name": "Douglas College",
#     "Published Date": "May. 9, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/student-assistant-computer-lab-computer-science-new-westminster-1333313"
# }
# {
#     "Job Title": "Dev Ops Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/dev-ops-developer-burnaby-1118104"
# }
# {
#     "Job Title": "Senior Software Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 13, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-software-developer-burnaby-1097711"
# }
# {
#     "Job Title": "QA Automation Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/qa-automation-developer-burnaby-1075830"
# }
# {
#     "Job Title": "DevOps Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 11, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/devops-developer-burnaby-1075831"
# }
# {
#     "Job Title": "Release QA 2",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 15, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/release-qa-2-burnaby-940721"
# }
# {
#     "Job Title": "Information Security Specialist",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/information-security-specialist-burnaby-1118105"
# }
# {
#     "Job Title": "Software Developer (C/C++)",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 9, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/software-developer-c-c-burnaby-1101770"
# }
# {
#     "Job Title": "IT Specialist - FortiGuard",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/it-specialist-fortiguard-burnaby-1107266"
# }
# {
#     "Job Title": "Software QA - FortiOS",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/software-qa-fortios-burnaby-1080006"
# }
# {
#     "Job Title": "Embedded Software Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 9, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/embedded-software-developer-burnaby-1008171"
# }
# {
#     "Job Title": "Cloud Services DevOps Specialist",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/cloud-services-devops-specialist-burnaby-945392"
# }
# {
#     "Job Title": "Senior DevOps Specialist",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 15, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-devops-specialist-burnaby-1088223"
# }
# {
#     "Job Title": "Cloud Services DevOps Specialist 2",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 8, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/cloud-services-devops-specialist-2-burnaby-945393"
# }
# {
#     "Job Title": "Release QA Specialist",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/release-qa-specialist-burnaby-1118106"
# }
# {
#     "Job Title": "Embedded Software Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/embedded-software-developer-burnaby-1109015"
# }
# {
#     "Job Title": "Release QA Specialist",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 13, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/release-qa-specialist-burnaby-1110117"
# }
# {
#     "Job Title": "Dev Ops Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 13, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/dev-ops-developer-burnaby-1110118"
# }
# {
#     "Job Title": "Machine Learning Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/machine-learning-developer-burnaby-1040395"
# }
# {
#     "Job Title": "Senior DevOps Specialist",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 11, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-devops-specialist-burnaby-1053576"
# }
# {
#     "Job Title": "IPS Analyst 1",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 9, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/ips-analyst-1-burnaby-418750"
# }
# {
#     "Job Title": "Release QA 1",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 8, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/release-qa-1-burnaby-905767"
# }
# {
#     "Job Title": "Jr. Embedded Software Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 8, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/jr-embedded-software-developer-burnaby-869519"
# }
# {
#     "Job Title": "Full Stack Developer",
#     "Company Name": "ShopHopper",
#     "Published Date": "Apr. 28, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/full-stack-developer-kelowna-1419009"
# }
# {
#     "Job Title": "Senior Software Engineer",
#     "Company Name": "Equest",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-software-engineer-vancouver-1363930"
# }
# {
#     "Job Title": "Senior Software Engineer",
#     "Company Name": "Equest",
#     "Published Date": "May. 9, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-software-engineer-vancouver-1247488"
# }
# {
#     "Job Title": "Threat Intelligence Security Researcher, Cyber Intelligence Centre",
#     "Company Name": "Deloitte",
#     "Published Date": "May. 8, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/threat-intelligence-security-researcher-cyber-intelligence-centre-canada-1362828"
# }
# {
#     "Job Title": "Data Engineer",
#     "Company Name": "Equest",
#     "Published Date": "May. 11, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/data-engineer-surrey-1345362"
# }
# {
#     "Job Title": "Full Stack Web Developer (contract)",
#     "Company Name": "Equest",
#     "Published Date": "May. 12, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/full-stack-web-developer-contract-richmond-1272612"
# }
# {
#     "Job Title": "Wildlife Data Specialist - BC Public Service",
#     "Company Name": "VIATEC",
#     "Published Date": "May. 13, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/wildlife-data-specialist-bc-public-service-nanaimo-victoria-1420865"
# }
# {
#     "Job Title": "Senior Software Engineer , Game Services",
#     "Company Name": "Equest",
#     "Published Date": "May. 15, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-software-engineer-game-services-vancouver-1142486"
# }
# {
#     "Job Title": "VM Specialist, Cyber Intelligence Centre",
#     "Company Name": "Deloitte",
#     "Published Date": "May. 8, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/vm-specialist-cyber-intelligence-centre-canada-1362827"
# }
# {
#     "Job Title": "Data Analyst",
#     "Company Name": "Equest",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/data-analyst-surrey-1363964"
# }
# {
#     "Job Title": "Technical Support Expert - FortiSOAR",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/technical-support-expert-fortisoar-burnaby-1011651"
# }
# {
#     "Job Title": "Consultant or Senior Consultant - Quality Engineering (QA) - Systems Engineering",
#     "Company Name": "Deloitte",
#     "Published Date": "May. 12, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/consultant-or-senior-consultant-quality-engineering-qa-systems-engineering-canada-1319135"
# }
# {
#     "Job Title": "Manager, Software Dev QA (Fortinet Distributed Network)",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 9, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/manager-software-dev-qa-fortinet-distributed-network-burnaby-1064410"
# }
# {
#     "Job Title": "Systems Software Developer - Polaris Motion",
#     "Company Name": "VIATEC",
#     "Published Date": "May. 11, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/systems-software-developer-polaris-motion-victoria-1411831"
# }
# {
#     "Job Title": "Oceanographer - ASL Environmental Sciences",
#     "Company Name": "VIATEC",
#     "Published Date": "May. 12, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/oceanographer-asl-environmental-sciences-victoria-1418744"
# }
# {
#     "Job Title": "Data Engineer - SAP Data Analytics, Omnia AI",
#     "Company Name": "Deloitte",
#     "Published Date": "May. 12, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/data-engineer-sap-data-analytics-omnia-ai-canada-1277149"
# }
# {
#     "Job Title": "Manager - Financial Engineering and Modeling, AML",
#     "Company Name": "Equest",
#     "Published Date": "May. 11, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/manager-financial-engineering-and-modeling-aml-canada-1269872"
# }
# {
#     "Job Title": "Manager / Senior Manager, Systems Engineering - Quality Engineering (QA)",
#     "Company Name": "Deloitte",
#     "Published Date": "May. 15, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/manager-senior-manager-systems-engineering-quality-engineering-qa-montreal-1234422"
# }
# {
#     "Job Title": "Ops Engineering Internship",
#     "Company Name": "Equest",
#     "Published Date": "May. 13, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/ops-engineering-internship-vancouver-1365551"
# }
# {
#     "Job Title": "Data & Analytics -  Senior Data Analyst",
#     "Company Name": "Aritzia",
#     "Published Date": "May. 15, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/data-analytics-senior-data-analyst-vancouver-1112382"
# }
# {
#     "Job Title": "Applications Software Developer - Polaris Motion CAD CAM, Animation, Simulation, and Virtual Reality (VR)",
#     "Company Name": "VIATEC",
#     "Published Date": "May. 15, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/applications-software-developer-polaris-motion-victoria-1414402"
# }
# {
#     "Job Title": "Data Engineer - Azure, Omnia AI",
#     "Company Name": "Deloitte",
#     "Published Date": "May. 12, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/data-engineer-azure-omnia-ai-canada-1277147"
# }
# {
#     "Job Title": "Enterprise Architect, Digital Platform",
#     "Company Name": "BMO",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/enterprise-architect-digital-platform-toronto-1271480"
# }
# {
#     "Job Title": "Senior Embedded Linux Software Engineer",
#     "Company Name": "Ballard Power Systems Inc.",
#     "Published Date": "May. 13, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-embedded-linux-software-engineer-vancouver-1292239"
# }
# {
#     "Job Title": "Data & Analytics - Senior Data Platform Engineer",
#     "Company Name": "Aritzia",
#     "Published Date": "May. 13, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/data-analytics-senior-data-platform-engineer-vancouver-1319484"
# }
# {
#     "Job Title": "Pricing Analyst",
#     "Company Name": "STEMCELL Technologies",
#     "Published Date": "May. 12, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/pricing-analyst-vancouver-1381197"
# }
# {
#     "Job Title": "Systems Test Engineer",
#     "Company Name": "STEMCELL Technologies",
#     "Published Date": "May. 11, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/systems-test-engineer-burnaby-1360354"
# }
# {
#     "Job Title": "Junior Data Engineer",
#     "Company Name": "Equest",
#     "Published Date": "May. 9, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/junior-data-engineer-vancouver-1247489"
# }
# {
#     "Job Title": "Senior Full Stack Software Engineer - Waterworth",
#     "Company Name": "VIATEC",
#     "Published Date": "May. 14, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-full-stack-software-engineer-waterworth-victoria-1412314"
# }
# {
#     "Job Title": "Voice and Collaboration Engineer, Project Services - Charter",
#     "Company Name": "VIATEC",
#     "Published Date": "May. 13, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/voice-and-collaboration-engineer-project-services-charter-victoria-1420862"
# }
# {
#     "Job Title": "Test Engineer",
#     "Company Name": "Equest",
#     "Published Date": "May. 15, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/test-engineer-richmond-1239471"
# }
# {
#     "Job Title": "Summer Co-op Student in Medical Physics - BC Cancer - Prince George",
#     "Company Name": "BC Cancer",
#     "Published Date": "May. 13, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/summer-co-op-student-in-medical-physics-bc-cancer-prince-george-prince-george-1422460"
# }
# {
#     "Job Title": "Enterprise Architect - Data and Analytics",
#     "Company Name": "BMO",
#     "Published Date": "May. 15, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/enterprise-architect-data-and-analytics-toronto-1160700"
# }
# {
#     "Job Title": "Software Development Engineer - Treyarch",
#     "Company Name": "Equest",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/software-development-engineer-treyarch-vancouver-1364125"
# }
# {
#     "Job Title": "Software Development Internship- Winter 2023",
#     "Company Name": "Equest",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/software-development-internship-winter-2023-vancouver-1364071"
# }
# {
#     "Job Title": "Director, Digital",
#     "Company Name": "Teck Resources",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/director-digital-vancouver-1413645"
# }
# {
#     "Job Title": "Project Services Team Lead - Charter",
#     "Company Name": "VIATEC",
#     "Published Date": "May. 13, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/project-services-team-lead-charter-victoria-1420864"
# }
# {
#     "Job Title": "Senior Systems Engineer, Bioinformatics",
#     "Company Name": "STEMCELL Technologies",
#     "Published Date": "May. 8, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-systems-engineer-bioinformatics-vancouver-1374283"
# }
# {
#     "Job Title": "Consultant / Senior Consultant -  Operations Management Consulting",
#     "Company Name": "KPMG",
#     "Published Date": "May. 12, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/consultant-senior-consultant-operations-management-consulting-vancouver-1311993"
# }
# {
#     "Job Title": "Senior Manager, Information Management and Data Analytics",
#     "Company Name": "KPMG",
#     "Published Date": "May. 12, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-manager-information-management-and-data-analytics-vancouver-1308367"
# }
# {
#     "Job Title": "Data Mining Engineer",
#     "Company Name": "Ecological Park Agriculture Inc",
#     "Published Date": "Apr. 21, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/data-mining-engineer-richmond-1417731"
# }
# {
#     "Job Title": "Product Development Leader",
#     "Company Name": "Delta-X Research",
#     "Published Date": "Apr. 19, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/product-development-leader-victoria-1417137"
# }
# {
#     "Job Title": "Software Development Internship-Data",
#     "Company Name": "Equest",
#     "Published Date": "May. 11, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/software-development-internship-data-vancouver-1349426"
# }
# {
#     "Job Title": "SAP iXp Intern - Developer",
#     "Company Name": "SAP",
#     "Published Date": "May. 13, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/sap-ixp-intern-developer-vancouver-1372772"
# }
# {
#     "Job Title": "SAP iXp Intern - DevOps Engineer",
#     "Company Name": "SAP",
#     "Published Date": "May. 11, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/sap-ixp-intern-devops-engineer-vancouver-1380867"
# }
# {
#     "Job Title": "Product Development Leader - Delta-X Research",
#     "Company Name": "VIATEC",
#     "Published Date": "May. 13, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/product-development-leader-delta-x-research-victoria-1417173"
# }
# {
#     "Job Title": "Laboratory Facilitator, Computing Science",
#     "Company Name": "Douglas College",
#     "Published Date": "May. 13, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/laboratory-facilitator-computing-science-new-westminster-1372284"
# }
# {
#     "Job Title": "SAP iXp Intern - Developer in Assembly and Build Operations",
#     "Company Name": "SAP",
#     "Published Date": "May. 13, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/sap-ixp-intern-developer-in-assembly-and-build-operations-vancouver-1372775"
# }
# {
#     "Job Title": "TIBCO Software Engineer, Omnia AI",
#     "Company Name": "Deloitte",
#     "Published Date": "May. 15, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/tibco-software-engineer-omnia-ai-vancouver-1313480"
# }
# {
#     "Job Title": "SAP Concur iXp Intern - Software Developer [Vancouver]",
#     "Company Name": "SAP",
#     "Published Date": "May. 8, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/sap-concur-ixp-intern-software-developer-vancouver-vancouver-1376833"
# }
# {
#     "Job Title": "Groundwater Modeller Vancouver, BC 2022-10-23",
#     "Company Name": "WSP Canada",
#     "Published Date": "May. 11, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/groundwater-modeller-vancouver-bc-2022-04-22-vancouver-1263232"
# }
# {
#     "Job Title": "Data Scientist, Data, Analytics, Evaluation and Reporting (DARE)",
#     "Company Name": "PHSA",
#     "Published Date": "May. 2, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/data-scientist-data-analytics-evaluation-and-reporting-dare-vancouver-1419698"
# }
# {
#     "Job Title": "SAP iXp Intern - Software Engineer [Vancouver]",
#     "Company Name": "SAP",
#     "Published Date": "May. 12, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/sap-ixp-intern-software-engineer-vancouver-vancouver-1372208"
# }
# {
#     "Job Title": "DevOps Engineer",
#     "Company Name": "SAP",
#     "Published Date": "May. 12, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/devops-engineer-vancouver-1375568"
# }
# {
#     "Job Title": "Senior Consultant, Cloud Engineer",
#     "Company Name": "KPMG",
#     "Published Date": "May. 15, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-consultant-cloud-engineer-vancouver-1212027"
# }

# %% [markdown]
# ## Scraping for Each Skill Set
#
# Now, we can modify the previous code so that the model scrapes all the result for each skill set. I'll search for `Python`, `SQL`, `Tableau`, and `Power BI`. I know `R` is used a lot in the field too, but it is hard to search because it contains a lot of non-related data. I apologize for that.

# %%
from bs4 import BeautifulSoup
import requests

base_url = "https://www.bcjobs.ca/search-jobs"
params = {
    "location": "",
    "range": "0",
    "freshness": "31",
    "categoryIds": "",
    "employerTypeIds": "",
    "positionTypeIds": "",
    "memberStatusIds": "",
    "careerLevelIds": "",
    "featuredEmployersOnly": "false",
    "trainingPositionsOnly": "false"
}

skill_list = ['python', 'sql', 'tableau', 'power bi']

results = {}

for skill in skill_list:
    params['q'] = skill
    
    html_text = requests.get(base_url, params=params).text
    soup = BeautifulSoup(html_text, "html.parser")
    total_results = int(soup.find("strong", {"data-outlet": "total"}).text)
    num_pages = total_results // 10 + 1 if total_results % 10 != 0 else total_results // 10
    
    # Scrape the job postings from all pages and store the results in a variable
    skill_result = []
    for page in range(1, num_pages + 1):
        params["page"] = page
        html_text = requests.get(base_url, params=params).text
        soup = BeautifulSoup(html_text, "html.parser")
        jobs = soup.find_all("a", class_="list-item-wrapper")

        for job in jobs:
            job_title = job.find("div", class_="list-item-title").text.strip()
            company_name = job.find("div", class_="list-divider flex-w100").text.strip()
            published_date = job.find("strong").text.strip()
            post_link = "https://www.bcjobs.ca" + job["href"]

            skill_result.append({
                "Job Title": job_title,
                "Company Name": company_name,
                "Published Date": published_date,
                "Link": post_link
            })

    # Store the result for this skill set in the dictionary
    results[skill] = skill_result

# %%
for job in results['sql']:
    print(json.dumps(job, indent=4))
# Out:
# {
#     "Job Title": "Software Application Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/software-application-developer-burnaby-1079338"
# }
# {
#     "Job Title": "Senior Software Applications Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 9, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-software-applications-developer-burnaby-987724"
# }
# {
#     "Job Title": "Software Applications Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 9, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/software-applications-developer-burnaby-987725"
# }
# {
#     "Job Title": "Senior .net/C# Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 9, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-net-c-developer-burnaby-987726"
# }
# {
#     "Job Title": "Sr. Dev Ops Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 15, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/sr-dev-ops-developer-burnaby-1116695"
# }
# {
#     "Job Title": "Intermediate Software Developer",
#     "Company Name": "Equest",
#     "Published Date": "May. 11, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/intermediate-software-developer-victoria-1327477"
# }
# {
#     "Job Title": "Business Systems Analyst (Pulp Manufacturing)",
#     "Company Name": "Canfor",
#     "Published Date": "May. 12, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/business-systems-analyst-pulp-manufacturing-prince-george-1300800"
# }
# {
#     "Job Title": "PowerBI Developer",
#     "Company Name": "Swim Recruiting",
#     "Published Date": "May. 4, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/powerbi-developer-vancouver-1420558"
# }
# {
#     "Job Title": "Senior Software Applications QA",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 9, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-software-applications-qa-burnaby-987723"
# }
# {
#     "Job Title": "Data Engineer - Azure, Omnia AI",
#     "Company Name": "Deloitte",
#     "Published Date": "May. 12, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/data-engineer-azure-omnia-ai-canada-1277147"
# }
# {
#     "Job Title": "ISL R27 - Senior Developer, Ebiz, Corporate IT",
#     "Company Name": "BC Liquor Distribution Branch",
#     "Published Date": "May. 12, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/isl-r27-senior-developer-ebiz-corporate-it-burnaby-1322835"
# }
# {
#     "Job Title": "Software Dev QA",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/software-dev-qa-burnaby-1077727"
# }
# {
#     "Job Title": "Software Dev QA",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/software-dev-qa-burnaby-1080005"
# }
# {
#     "Job Title": "Data Analyst",
#     "Company Name": "Equest",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/data-analyst-burnaby-1363995"
# }
# {
#     "Job Title": "Data Conversion Specialist",
#     "Company Name": "Equest",
#     "Published Date": "May. 9, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/data-conversion-specialist-victoria-1223592"
# }
# {
#     "Job Title": "ERP Specialist",
#     "Company Name": "Urban Systems Ltd.",
#     "Published Date": "May. 4, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/erp-specialist-kamloops-1420287"
# }
# {
#     "Job Title": "Data & Analytics - Senior Analytics Engineer",
#     "Company Name": "Aritzia",
#     "Published Date": "May. 15, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/data-analytics-senior-analytics-engineer-vancouver-1282507"
# }
# {
#     "Job Title": "Intermediate Software Developer",
#     "Company Name": "SMC Software Inc",
#     "Published Date": "Apr. 22, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/intermediate-software-developer-kelowna-1417772"
# }
# {
#     "Job Title": "Integration Architect",
#     "Company Name": "Best Buy Canada",
#     "Published Date": "May. 13, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/integration-architect-vancouver-1422643"
# }
# {
#     "Job Title": "ISL R27 Senior Developer SOA, OSB, Corporate IT",
#     "Company Name": "BC Liquor Distribution Branch",
#     "Published Date": "May. 13, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/isl-r27-senior-developer-soa-osb-corporate-it-burnaby-1323237"
# }
# {
#     "Job Title": "Software Developer (C/C++)",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/software-developer-c-c-burnaby-1095704"
# }
# {
#     "Job Title": "SENIOR SOFTWARE DEVELOPER",
#     "Company Name": "DDL Game Ltd",
#     "Published Date": "May. 13, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-software-developer-vancouver-1083912"
# }
# {
#     "Job Title": "Senior Full-Stack Web Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-full-stack-web-developer-burnaby-1085461"
# }
# {
#     "Job Title": "AB-Initio ETL Technical Specialist Business Intelligence-  (100% remote-virtual)",
#     "Company Name": "BMO",
#     "Published Date": "May. 9, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/etl-technical-specialist-business-intelligence-hybrid-role-toronto-1329398"
# }
# {
#     "Job Title": "Enterprise Architect - Data and Analytics",
#     "Company Name": "BMO",
#     "Published Date": "May. 15, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/enterprise-architect-data-and-analytics-toronto-1160700"
# }
# {
#     "Job Title": "Systems Analyst - Brentwood College Association",
#     "Company Name": "VIATEC",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/systems-analyst-brentwood-college-association-duncan-vancouver-island-1418208"
# }
# {
#     "Job Title": "Specialist Data Integration Data Analytics, Reporting & Evaluation",
#     "Company Name": "PHSA",
#     "Published Date": "May. 2, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/specialist-data-integration-data-analytics-reporting-evaluation-vancouver-1419696"
# }
# {
#     "Job Title": "Senior Software Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 11, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-software-developer-burnaby-954761"
# }
# {
#     "Job Title": "Application Support Analyst",
#     "Company Name": "Coast Capital Savings",
#     "Published Date": "May. 15, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/application-support-analyst-surrey-1362247"
# }
# {
#     "Job Title": "Systems Consultant",
#     "Company Name": "Microserve",
#     "Published Date": "May. 15, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/systems-consultant-canada-remote-1389328"
# }
# {
#     "Job Title": "Software Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 15, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/software-developer-burnaby-1089046"
# }
# {
#     "Job Title": "Senior Software Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 13, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-software-developer-burnaby-1097711"
# }
# {
#     "Job Title": "QA Automation Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/qa-automation-developer-burnaby-1075830"
# }
# {
#     "Job Title": "Fraud Risk Analyst",
#     "Company Name": "Coast Capital Savings",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/fraud-risk-analyst-surrey-1364713"
# }
# {
#     "Job Title": "Machine Learning Developer",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/machine-learning-developer-burnaby-1040395"
# }
# {
#     "Job Title": "Senior DevOps Specialist",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 11, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-devops-specialist-burnaby-1053576"
# }
# {
#     "Job Title": "Release QA 1",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 8, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/release-qa-1-burnaby-905767"
# }
# {
#     "Job Title": "Conseiller support technique",
#     "Company Name": "Equest",
#     "Published Date": "May. 13, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/conseiller-support-technique-vancouver-1348989"
# }
# {
#     "Job Title": "Senior Consultant, Full Stack Developer",
#     "Company Name": "KPMG",
#     "Published Date": "May. 8, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-consultant-full-stack-developer-vancouver-1332852"
# }
# {
#     "Job Title": "Project Controls Specialist",
#     "Company Name": "Horizon Recruitment Inc.",
#     "Published Date": "May. 13, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/project-controls-specialist-vancouver-1384985"
# }
# {
#     "Job Title": "Product Owner (Data Warehouse)",
#     "Company Name": "IT/IQ Tech Recruiters",
#     "Published Date": "May. 11, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/product-owner-data-warehouse-burnaby-727677"
# }
# {
#     "Job Title": "SAP Concur iXp Intern - Software Developer [Vancouver]",
#     "Company Name": "SAP",
#     "Published Date": "May. 8, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/sap-concur-ixp-intern-software-developer-vancouver-vancouver-1376833"
# }
# {
#     "Job Title": "Developer  - Microsoft 365 - Content Services",
#     "Company Name": "Deloitte",
#     "Published Date": "May. 8, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/developer-microsoft-365-content-services-vancouver-1353535"
# }
# {
#     "Job Title": "Architect - Microsoft 365, Lead - Content Services",
#     "Company Name": "Deloitte",
#     "Published Date": "May. 8, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/architect-microsoft-365-lead-content-services-vancouver-1353536"
# }
# {
#     "Job Title": "Data QA Engineer",
#     "Company Name": "Swim Recruiting",
#     "Published Date": "Apr. 27, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/data-qa-engineer-vancouver-1418948"
# }
# {
#     "Job Title": "Senior Consultant, Cloud MSS, OperateNext",
#     "Company Name": "Deloitte",
#     "Published Date": "May. 8, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-consultant-cloud-mss-risk-advisory-canada-1362830"
# }
# {
#     "Job Title": "ERP Specialist",
#     "Company Name": "Urban Systems Ltd.",
#     "Published Date": "May. 2, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/erp-specialist-kamloops-kelowna-vancouver-1419937"
# }
# {
#     "Job Title": "Specialist, Business Intelligence, Strategic Information Management, BC Mental Health & Substance Use Services - Vancouver, BC",
#     "Company Name": "BC Mental Health and Substance Use Services",
#     "Published Date": "Apr. 29, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/specialist-business-intelligence-strategic-information-management-bc-mental-health-substance-use-services-vancouver-bc-vancouver-1363646"
# }
# {
#     "Job Title": "Data Engineer",
#     "Company Name": "Equest",
#     "Published Date": "May. 11, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/data-engineer-surrey-1345362"
# }
# {
#     "Job Title": "Senior Solution Architect",
#     "Company Name": "BMO",
#     "Published Date": "May. 12, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-solution-architect-canada-1315346"
# }
# {
#     "Job Title": "Consultant or Senior Consultant - Architecture - Systems Engineering",
#     "Company Name": "Deloitte",
#     "Published Date": "May. 12, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/consultant-or-senior-consultant-architecture-systems-engineering-canada-1319134"
# }
# {
#     "Job Title": "Full Stack Developer",
#     "Company Name": "Ledcor",
#     "Published Date": "May. 13, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/full-stack-developer-vancouver-1120190"
# }
# {
#     "Job Title": "Industrial Control System Designer",
#     "Company Name": "BID Group",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/industrial-control-system-designer-prince-george-1384680"
# }
# {
#     "Job Title": "Field Automation Service Technician",
#     "Company Name": "BID Group",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/field-automation-service-technician-prince-george-1384681"
# }
# {
#     "Job Title": "Responsable technique - Support applicatif / succ\u00e8s client Qu\u00e9bec",
#     "Company Name": "Equest",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/responsable-technique-support-applicatif-succ-s-client-qu-bec-vancouver-1364121"
# }
# {
#     "Job Title": "Full Stack Web Developer (contract)",
#     "Company Name": "Equest",
#     "Published Date": "May. 12, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/full-stack-web-developer-contract-richmond-1272612"
# }
# {
#     "Job Title": "Application Support Analyst - Mosaic Forest Management",
#     "Company Name": "VIATEC",
#     "Published Date": "May. 12, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/application-support-analyst-mosaic-forest-management-nanaimo-1416853"
# }
# {
#     "Job Title": "Field Service Engineer",
#     "Company Name": "BID Group",
#     "Published Date": "May. 15, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/field-service-engineer-prince-george-1369830"
# }
# {
#     "Job Title": "Data Analyst",
#     "Company Name": "Equest",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/data-analyst-surrey-1363964"
# }
# {
#     "Job Title": "Senior Consultant, Cloud Engineer",
#     "Company Name": "KPMG",
#     "Published Date": "May. 15, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-consultant-cloud-engineer-vancouver-1212027"
# }
# {
#     "Job Title": "Quality Analyst",
#     "Company Name": "Ledcor",
#     "Published Date": "May. 11, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/quality-analyst-vancouver-1080928"
# }
# {
#     "Job Title": "Technical Support Expert - FortiSOAR",
#     "Company Name": "Fortinet",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/technical-support-expert-fortisoar-burnaby-1011651"
# }
# {
#     "Job Title": "Network Systems Analyst",
#     "Company Name": "The City of West Kelowna",
#     "Published Date": "Apr. 27, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/network-systems-analyst-west-kelowna-1418755"
# }
# {
#     "Job Title": "Systems Analyst, Clinical Solutions, IMITS",
#     "Company Name": "PHSA",
#     "Published Date": "May. 12, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/systems-analyst-clinical-solutions-imits-vancouver-1422195"
# }
# {
#     "Job Title": "Data Engineer - SAP Data Analytics, Omnia AI",
#     "Company Name": "Deloitte",
#     "Published Date": "May. 12, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/data-engineer-sap-data-analytics-omnia-ai-canada-1277149"
# }
# {
#     "Job Title": "Manager - Financial Engineering and Modeling, AML",
#     "Company Name": "Equest",
#     "Published Date": "May. 11, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/manager-financial-engineering-and-modeling-aml-canada-1269872"
# }
# {
#     "Job Title": "Technical and Application Support Analyst",
#     "Company Name": "Equest",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/technical-and-application-support-analyst-burnaby-1144171"
# }
# {
#     "Job Title": "Data & Analytics -  Senior Data Analyst",
#     "Company Name": "Aritzia",
#     "Published Date": "May. 15, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/data-analytics-senior-data-analyst-vancouver-1112382"
# }
# {
#     "Job Title": "Smart Cities Software Application Developer (Senior or Intermediate) - LED Roadway Lighting",
#     "Company Name": "VIATEC",
#     "Published Date": "May. 8, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/smart-cities-software-application-developer-senior-or-intermediate-led-roadway-lighting-victoria-1416196"
# }
# {
#     "Job Title": "Application Support and Test Analyst Public Health Information Systems",
#     "Company Name": "PHSA",
#     "Published Date": "Apr. 26, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/application-support-and-test-analyst-public-health-information-systems-vancouver-1418537"
# }
# {
#     "Job Title": "Junior Support Developer",
#     "Company Name": "Imagine Everything",
#     "Published Date": "May. 9, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/junior-support-developer-kelowna-1421358"
# }
# {
#     "Job Title": "Data & Analytics - Senior Data Platform Engineer",
#     "Company Name": "Aritzia",
#     "Published Date": "May. 13, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/data-analytics-senior-data-platform-engineer-vancouver-1319484"
# }
# {
#     "Job Title": "Manager SCM Business Improvement",
#     "Company Name": "Avigilon",
#     "Published Date": "May. 11, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/manager-scm-business-improvement-richmond-721589"
# }
# {
#     "Job Title": "Senior Manager, Supply Chain Technology Operations",
#     "Company Name": "Aritzia",
#     "Published Date": "May. 9, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-manager-supply-chain-technology-operations-vancouver-1363514"
# }
# {
#     "Job Title": "Junior Data Engineer",
#     "Company Name": "Equest",
#     "Published Date": "May. 9, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/junior-data-engineer-vancouver-1247489"
# }
# {
#     "Job Title": "Business Solutions Analyst - Data Services - BCI",
#     "Company Name": "VIATEC",
#     "Published Date": "May. 12, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/business-solutions-analyst-data-services-bci-victoria-1420562"
# }
# {
#     "Job Title": "Manager, Technology and Operations Inter Campus Operations",
#     "Company Name": "PHSA",
#     "Published Date": "Apr. 22, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/manager-technology-and-operations-inter-campus-operations-vancouver-1417792"
# }
# {
#     "Job Title": "Systems Analyst, Clinical Solutions, IMITS",
#     "Company Name": "PHSA",
#     "Published Date": "Apr. 29, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/systems-analyst-clinical-solutions-imits-vancouver-1419244"
# }
# {
#     "Job Title": "Software Development Engineer - Treyarch",
#     "Company Name": "Equest",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/software-development-engineer-treyarch-vancouver-1364125"
# }
# {
#     "Job Title": "Software Development Internship- Winter 2023",
#     "Company Name": "Equest",
#     "Published Date": "May. 10, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/software-development-internship-winter-2023-vancouver-1364071"
# }
# {
#     "Job Title": "Systems Administrator (BC or AB Remote)",
#     "Company Name": "Equest",
#     "Published Date": "May. 13, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/systems-administrator-bc-or-ab-remote-surrey-1259757"
# }
# {
#     "Job Title": "Senior Manager, Information Management and Data Analytics",
#     "Company Name": "KPMG",
#     "Published Date": "May. 12, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-manager-information-management-and-data-analytics-vancouver-1308367"
# }
# {
#     "Job Title": "Senior Full-Stack Software Product Developer",
#     "Company Name": "STEMCELL Technologies",
#     "Published Date": "May. 15, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/full-stack-software-product-developer-burnaby-1331020"
# }
# {
#     "Job Title": "Drupal Developer",
#     "Company Name": "PHSA",
#     "Published Date": "May. 3, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/drupal-developer-british-columbia-1419990"
# }
# {
#     "Job Title": "Software Development Internship-Data",
#     "Company Name": "Equest",
#     "Published Date": "May. 11, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/software-development-internship-data-vancouver-1349426"
# }
# {
#     "Job Title": "SAP iXp Intern - Developer",
#     "Company Name": "SAP",
#     "Published Date": "May. 13, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/sap-ixp-intern-developer-vancouver-1372772"
# }
# {
#     "Job Title": "Senior Programmer Analyst",
#     "Company Name": "BCLC",
#     "Published Date": "May. 15, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-programmer-analyst-kamloops-1348326"
# }
# {
#     "Job Title": "Senior Programmer Analyst",
#     "Company Name": "BCLC",
#     "Published Date": "May. 15, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-programmer-analyst-kamloops-1348327"
# }
# {
#     "Job Title": "Biostatistics and Data Linkage Leader - BC Centre for Disease Control",
#     "Company Name": "BC Centre for Disease Control",
#     "Published Date": "Apr. 29, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/biostatistics-and-data-linkage-leader-bc-centre-for-disease-control-vancouver-1419230"
# }
# {
#     "Job Title": "SAP iXp Intern - Technical Project Coordinator",
#     "Company Name": "SAP",
#     "Published Date": "May. 11, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/sap-ixp-intern-technical-project-coordinator-vancouver-1360722"
# }
# {
#     "Job Title": "TIBCO Software Engineer, Omnia AI",
#     "Company Name": "Deloitte",
#     "Published Date": "May. 15, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/tibco-software-engineer-omnia-ai-vancouver-1313480"
# }
# {
#     "Job Title": "Solutions Architect - VertiGIS",
#     "Company Name": "VIATEC",
#     "Published Date": "May. 11, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/solutions-architect-vertigis-victoria-1416568"
# }
# {
#     "Job Title": "Data Scientist, Data, Analytics, Evaluation and Reporting (DARE)",
#     "Company Name": "PHSA",
#     "Published Date": "May. 2, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/data-scientist-data-analytics-evaluation-and-reporting-dare-vancouver-1419698"
# }
# {
#     "Job Title": "Biostatistician, Epidemiology - BC Centre for Disease Control",
#     "Company Name": "BC Centre for Disease Control",
#     "Published Date": "May. 2, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/biostatistician-epidemiology-bc-centre-for-disease-control-vancouver-1419645"
# }
# {
#     "Job Title": "DevOps Engineer",
#     "Company Name": "SAP",
#     "Published Date": "May. 12, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/devops-engineer-vancouver-1375568"
# }
# {
#     "Job Title": "Senior Statistician, BCEHS",
#     "Company Name": "BC Emergency Health Services",
#     "Published Date": "May. 11, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-statistician-bcehs-vancouver-1421908"
# }
# {
#     "Job Title": "Biostatistics and Data Linkage Leader - BC Centre for Disease Control",
#     "Company Name": "BC Centre for Disease Control",
#     "Published Date": "May. 4, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/biostatistics-and-data-linkage-leader-bc-centre-for-disease-control-british-columbia-1420306"
# }
# {
#     "Job Title": "Senior Database Administrator",
#     "Company Name": "PHSA",
#     "Published Date": "May. 12, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-database-administrator-burnaby-1422199"
# }
# {
#     "Job Title": "Business Analyst",
#     "Company Name": "PHSA",
#     "Published Date": "Apr. 20, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/business-analyst-saanichton-1417202"
# }
# {
#     "Job Title": "Senior Application Programmer Analyst, IMITS",
#     "Company Name": "PHSA",
#     "Published Date": "May. 12, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-application-programmer-analyst-imits-burnaby-1422209"
# }
# {
#     "Job Title": "Senior Application Programmer Analyst, IMITS",
#     "Company Name": "PHSA",
#     "Published Date": "May. 12, 2023",
#     "Link": "https://www.bcjobs.ca/jobs/senior-application-programmer-analyst-imits-burnaby-1422210"
# }

# %%
print(f"There are {len(results['python'])} job postings for Python")
print(f"There are {len(results['sql'])} job postings for SQL")
print(f"There are {len(results['tableau'])} job postings for Tableau")
print(f"There are {len(results['power bi'])} job postings for Power BI")
# Out:
# There are 115 job postings for Python
# There are 101 job postings for SQL
# There are 22 job postings for Tableau
# There are 43 job postings for Power BI

# %% [markdown]
# ## Conclusion
#
# After scraping the BCJobs website, we can see that Python has the most job postings, with 115 results. However, we need to consider that this search includes not only data-related jobs, but also software developer and other tech jobs. SQL is the second most in-demand skill with 101 job postings, followed by Power BI with 43 job postings. Interestingly, Tableau only has 22 job postings. This suggests that while Tableau is a valuable tool for data visualization, it may not be as widely used as Power BI in the BC job market.
#
# Overall, this model provides a simple and efficient way to compare the demand for different skill sets and access job postings and links. For future improvements, an automated updating system could be added to eliminate the need for manual updates and provide real-time job postings. Additionally, a notification system could be developed to alert users when new job postings are available for a specific skill set.
